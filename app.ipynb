# %%
# Import the necessary libraries

import tensorflow as tf
import numpy as np
import pandas as pd
from PIL import Image
from io import BytesIO
from flask import Flask, jsonify, request, render_template

import json
import pickle

# %%
class Garbage_Collection_Point:
    garbage_type = ''
    collection_points = ['']

# %%
class_labels = ['battery','brown-glass','cardboard','paper','plastic','shoes']

collection_points = {"collection point": ['Ecowrap',
                                          'Ecowrap',
                                          'Ecowrap',
                                          'RaddiDedo',
                                          'RaddiDedo',
                                          'Zero Waste Recycling Pvt Ltd',
                                          'Zero Waste Recycling Pvt Ltd',
                                          'Detoxen Enviro Solutions',
                                          'Detoxen Enviro Solutions',
                                          'Detoxen Enviro Solutions',
                                          'Detoxen Enviro Solutions',
                                          'Ecowrap',
                                          'Ecowrap',
                                          'Ecowrap'],
                     "garbage_type": ['battery','brown-glass','cardboard',
                                      'brown-glass','cardboard',
                                      'paper','plastic',
                                      'battery','brown-glass','cardboard','shoes',
                                      'brown-glass','cardboard', 'shoes'
                                     ],
                     }

garbage_collection_point_df = pd.DataFrame(collection_points)
#garbage_collection_point_df.sort_values(by='garbage_type')

# %%
# testing code
# result = garbage_collection_point_df.loc[garbage_collection_point_df['garbage_type'] == 'battery', 'collection point'].tolist()
# #create object
# collection_points = Garbage_Collection_Point()
# collection_points.garbage_type = "battery"
# collection_points.collection_points = result

# predict_result = json.dumps(collection_points.__dict__)
    
# print (predict_result)

# %%
# 1. define a prediction function

def predict_garbage(model, image_bytes):
    
    # Preprocess the image    
    image_bytes = image_bytes.resize((120, 120))
    image_bytes = np.array(image_bytes) / 255.0
    image_bytes = np.expand_dims(image_bytes, axis=0)
    
    # Make the prediction
    prediction = model.predict(image_bytes)
    predicted_class = class_labels[np.argmax(prediction)] 
    
    result = garbage_collection_point_df.loc[garbage_collection_point_df['garbage_type'] == predicted_class, 'collection point'].tolist()
    
    #create object
    collection_points = Garbage_Collection_Point()
    collection_points.garbage_type = predicted_class
    collection_points.collection_points = result
    
    predict_result = json.dumps(collection_points.__dict__)
    
    return predict_result

# %%
# 2. create an instance of the flask class

app = Flask(__name__, template_folder='templates')

# %%
# 3. load the model for predict

with open('models/garbage_classification_model_pickle.pkl', 'rb') as file:
    model = pickle.load(file)
# Out:
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-03-26 17:15:26        87608
# metadata.json                                  2023-03-26 17:15:26           64
# variables.h5                                   2023-03-26 17:15:28     99740752
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\activation
# ......vars
# ...layers\activation_1
# ......vars
# ...layers\activation_10
# ......vars
# ...layers\activation_11
# ......vars
# ...layers\activation_12
# ......vars
# ...layers\activation_13
# ......vars
# ...layers\activation_14
# ......vars
# ...layers\activation_15
# ......vars
# ...layers\activation_16
# ......vars
# ...layers\activation_17
# ......vars
# ...layers\activation_18
# ......vars
# ...layers\activation_19
# ......vars
# ...layers\activation_2
# ......vars
# ...layers\activation_20
# ......vars
# ...layers\activation_21
# ......vars
# ...layers\activation_22
# ......vars
# ...layers\activation_23
# ......vars
# ...layers\activation_24
# ......vars
# ...layers\activation_25
# ......vars
# ...layers\activation_26
# ......vars
# ...layers\activation_27
# ......vars
# ...layers\activation_28
# ......vars
# ...layers\activation_29
# ......vars
# ...layers\activation_3
# ......vars
# ...layers\activation_30
# ......vars
# ...layers\activation_31
# ......vars
# ...layers\activation_32
# ......vars
# ...layers\activation_33
# ......vars
# ...layers\activation_34
# ......vars
# ...layers\activation_35
# ......vars
# ...layers\activation_36
# ......vars
# ...layers\activation_37
# ......vars
# ...layers\activation_38
# ......vars
# ...layers\activation_39
# ......vars
# ...layers\activation_4
# ......vars
# ...layers\activation_40
# ......vars
# ...layers\activation_41
# ......vars
# ...layers\activation_42
# ......vars
# ...layers\activation_43
# ......vars
# ...layers\activation_44
# ......vars
# ...layers\activation_45
# ......vars
# ...layers\activation_46
# ......vars
# ...layers\activation_47
# ......vars
# ...layers\activation_48
# ......vars
# ...layers\activation_5
# ......vars
# ...layers\activation_6
# ......vars
# ...layers\activation_7
# ......vars
# ...layers\activation_8
# ......vars
# ...layers\activation_9
# ......vars
# ...layers\add
# ......vars
# ...layers\add_1
# ......vars
# ...layers\add_10
# ......vars
# ...layers\add_11
# ......vars
# ...layers\add_12
# ......vars
# ...layers\add_13
# ......vars
# ...layers\add_14
# ......vars
# ...layers\add_15
# ......vars
# ...layers\add_2
# ......vars
# ...layers\add_3
# ......vars
# ...layers\add_4
# ......vars
# ...layers\add_5
# ......vars
# ...layers\add_6
# ......vars
# ...layers\add_7
# ......vars
# ...layers\add_8
# ......vars
# ...layers\add_9
# ......vars
# ...layers\batch_normalization
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_1
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_10
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_11
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_12
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_13
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_14
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_15
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_16
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_17
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_18
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_19
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_2
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_20
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_21
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_22
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_23
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_24
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_25
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_26
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_27
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_28
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_29
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_3
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_30
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_31
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_32
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_33
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_34
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_35
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_36
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_37
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_38
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_39
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_4
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_40
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_41
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_42
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_43
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_44
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_45
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_46
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_47
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_48
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_49
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_5
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_50
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_51
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_52
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_6
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_7
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_8
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\batch_normalization_9
# ......vars
# .........0
# .........1
# .........2
# .........3
# ...layers\conv2d
# ......vars
# .........0
# .........1
# ...layers\conv2d_1
# ......vars
# .........0
# .........1
# ...layers\conv2d_10
# ......vars
# .........0
# .........1
# ...layers\conv2d_11
# ......vars
# .........0
# .........1
# ...layers\conv2d_12
# ......vars
# .........0
# .........1
# ...layers\conv2d_13
# ......vars
# .........0
# .........1
# ...layers\conv2d_14
# ......vars
# .........0
# .........1
# ...layers\conv2d_15
# ......vars
# .........0
# .........1
# ...layers\conv2d_16
# ......vars
# .........0
# .........1
# ...layers\conv2d_17
# ......vars
# .........0
# .........1
# ...layers\conv2d_18
# ......vars
# .........0
# .........1
# ...layers\conv2d_19
# ......vars
# .........0
# .........1
# ...layers\conv2d_2
# ......vars
# .........0
# .........1
# ...layers\conv2d_20
# ......vars
# .........0
# .........1
# ...layers\conv2d_21
# ......vars
# .........0
# .........1
# ...layers\conv2d_22
# ......vars
# .........0
# .........1
# ...layers\conv2d_23
# ......vars
# .........0
# .........1
# ...layers\conv2d_24
# ......vars
# .........0
# .........1
# ...layers\conv2d_25
# ......vars
# .........0
# .........1
# ...layers\conv2d_26
# ......vars
# .........0
# .........1
# ...layers\conv2d_27
# ......vars
# .........0
# .........1
# ...layers\conv2d_28
# ......vars
# .........0
# .........1
# ...layers\conv2d_29
# ......vars
# .........0
# .........1
# ...layers\conv2d_3
# ......vars
# .........0
# .........1
# ...layers\conv2d_30
# ......vars
# .........0
# .........1
# ...layers\conv2d_31
# ......vars
# .........0
# .........1
# ...layers\conv2d_32
# ......vars
# .........0
# .........1
# ...layers\conv2d_33
# ......vars
# .........0
# .........1
# ...layers\conv2d_34
# ......vars
# .........0
# .........1
# ...layers\conv2d_35
# ......vars
# .........0
# .........1
# ...layers\conv2d_36
# ......vars
# .........0
# .........1
# ...layers\conv2d_37
# ......vars
# .........0
# .........1
# ...layers\conv2d_38
# ......vars
# .........0
# .........1
# ...layers\conv2d_39
# ......vars
# .........0
# .........1
# ...layers\conv2d_4
# ......vars
# .........0
# .........1
# ...layers\conv2d_40
# ......vars
# .........0
# .........1
# ...layers\conv2d_41
# ......vars
# .........0
# .........1
# ...layers\conv2d_42
# ......vars
# .........0
# .........1
# ...layers\conv2d_43
# ......vars
# .........0
# .........1
# ...layers\conv2d_44
# ......vars
# .........0
# .........1
# ...layers\conv2d_45
# ......vars
# .........0
# .........1
# ...layers\conv2d_46
# ......vars
# .........0
# .........1
# ...layers\conv2d_47
# ......vars
# .........0
# .........1
# ...layers\conv2d_48
# ......vars
# .........0
# .........1
# ...layers\conv2d_49
# ......vars
# .........0
# .........1
# ...layers\conv2d_5
# ......vars
# .........0
# .........1
# ...layers\conv2d_50
# ......vars
# .........0
# .........1
# ...layers\conv2d_51
# ......vars
# .........0
# .........1
# ...layers\conv2d_52
# ......vars
# .........0
# .........1
# ...layers\conv2d_6
# ......vars
# .........0
# .........1
# ...layers\conv2d_7
# ......vars
# .........0
# .........1
# ...layers\conv2d_8
# ......vars
# .........0
# .........1
# ...layers\conv2d_9
# ......vars
# .........0
# .........1
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dense_4
# ......vars
# .........0
# .........1
# ...layers\global_average_pooling2d
# ......vars
# ...layers\input_layer
# ......vars
# ...layers\max_pooling2d
# ......vars
# ...layers\zero_padding2d
# ......vars
# ...layers\zero_padding2d_1
# ......vars
# ...metrics\mean
# ......vars
# .........0
# .........1
# ...metrics\mean_metric_wrapper
# ......vars
# .........0
# .........1
# ...vars

# %%
# 4. set up our home page

@app.route('/', methods=['GET'])
@app.route('/index', methods=['GET'])

# create a separate index.html page and then load it
def index():
    """Renders the home page, with a list of all polls."""
    
    return render_template('index.html', title='Home')

# %%
# 5. define a new route to predict

@app.route('/predict', methods=['POST'])
def predict():
    
    # validation
    # Check if request contains a file
    if 'image' not in request.files:
        return jsonify({'error_message': "Request file is empty!"})
    
    # get the data from the request
    image_data = request.files['image'].read()
    image_bytes = Image.open(BytesIO(image_data))
    
    # make predictions on the data
    prediction_result = predict_garbage(model, image_bytes)   
    
    return prediction_result

# %%
# 6. allows the jupyter notebook to run flask using python app.py

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [26/Mar/2023 18:23:47] "GET / HTTP/1.1" 200 -
# 1/1 [==============================] - 1s 1s/step
# 127.0.0.1 - - [26/Mar/2023 18:23:52] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 67ms/step
# 127.0.0.1 - - [26/Mar/2023 18:24:11] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 66ms/step
# 127.0.0.1 - - [26/Mar/2023 18:24:37] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 75ms/step
# 127.0.0.1 - - [26/Mar/2023 18:26:14] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 74ms/step
# 127.0.0.1 - - [26/Mar/2023 18:29:37] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 67ms/step
# 127.0.0.1 - - [26/Mar/2023 18:29:43] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 78ms/step
# 127.0.0.1 - - [26/Mar/2023 18:29:49] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 407ms/step
# 127.0.0.1 - - [26/Mar/2023 19:07:50] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 80ms/step
# 127.0.0.1 - - [26/Mar/2023 19:08:00] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 64ms/step
# 127.0.0.1 - - [26/Mar/2023 19:08:07] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 71ms/step
# 127.0.0.1 - - [26/Mar/2023 19:13:30] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 64ms/step
# 127.0.0.1 - - [26/Mar/2023 19:13:39] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 59ms/step
# 127.0.0.1 - - [26/Mar/2023 19:13:43] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 59ms/step
# 127.0.0.1 - - [26/Mar/2023 19:13:48] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 65ms/step
# 127.0.0.1 - - [26/Mar/2023 19:13:52] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 68ms/step
# 127.0.0.1 - - [26/Mar/2023 19:13:58] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 72ms/step
# 127.0.0.1 - - [26/Mar/2023 20:57:54] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 69ms/step
# 127.0.0.1 - - [26/Mar/2023 20:58:28] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 63ms/step
# 127.0.0.1 - - [26/Mar/2023 20:58:42] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 66ms/step
# 127.0.0.1 - - [26/Mar/2023 21:00:12] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 74ms/step
# 127.0.0.1 - - [26/Mar/2023 21:00:28] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 65ms/step
# 127.0.0.1 - - [26/Mar/2023 21:00:34] "POST /predict HTTP/1.1" 200 -
